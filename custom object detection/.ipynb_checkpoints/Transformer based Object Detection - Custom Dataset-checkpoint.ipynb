# %%
# !python --version
# !nvcc --version
# !pip list
# Out:
# Python 3.10.12
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# Package                          Version
# -------------------------------- ------------
# absl-py                          1.4.0
# aiohttp                          3.8.5
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.2.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      21.3.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.0
# arviz                            0.15.1
# astropy                          5.2.2
# astunparse                       1.6.3
# async-timeout                    4.0.2
# attrs                            23.1.0
# audioread                        3.0.0
# autograd                         1.6.2
# Babel                            2.12.1
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# bleach                           6.0.0
# blinker                          1.4
# blis                             0.7.10
# blosc2                           2.0.0
# bokeh                            3.1.1
# branca                           0.6.0
# build                            0.10.0
# CacheControl                     0.13.1
# cachetools                       5.3.1
# catalogue                        2.0.9
# certifi                          2023.7.22
# cffi                             1.15.1
# chardet                          4.0.0
# charset-normalizer               2.0.12
# chex                             0.1.7
# click                            8.1.6
# click-plugins                    1.1.1
# cligj                            0.7.2
# cloudpickle                      2.2.1
# cmake                            3.25.2
# cmdstanpy                        1.1.0
# colorama                         0.4.6
# colorcet                         3.0.1
# colorlover                       0.3.0
# community                        1.0.0b1
# confection                       0.1.0
# cons                             0.4.6
# contextlib2                      21.6.0
# contourpy                        1.1.0
# convertdate                      2.4.0
# cryptography                     3.4.8
# cufflinks                        0.17.3
# cupy-cuda11x                     11.0.0
# cvxopt                           1.3.1
# cvxpy                            1.3.2
# cycler                           0.11.0
# cymem                            2.0.7
# Cython                           0.29.36
# dask                             2022.12.1
# datascience                      0.17.6
# db-dtypes                        1.1.1
# debugpy                          1.6.6
# decorator                        4.4.2
# defusedxml                       0.7.1
# distributed                      2022.12.1
# distro                           1.7.0
# dlib                             19.24.2
# dm-tree                          0.1.8
# docutils                         0.16
# dopamine-rl                      4.0.6
# duckdb                           0.8.1
# earthengine-api                  0.1.360
# easydict                         1.10
# ecos                             2.0.12
# editdistance                     0.6.2
# en-core-web-sm                   3.5.0
# entrypoints                      0.4
# ephem                            4.1.4
# et-xmlfile                       1.1.0
# etils                            1.4.0
# etuples                          0.3.9
# exceptiongroup                   1.1.2
# fastai                           2.7.12
# fastcore                         1.5.29
# fastdownload                     0.0.7
# fastjsonschema                   2.18.0
# fastprogress                     1.0.3
# fastrlock                        0.8.1
# filelock                         3.12.2
# Fiona                            1.9.4.post1
# firebase-admin                   5.3.0
# Flask                            2.2.5
# flatbuffers                      23.5.26
# flax                             0.7.0
# folium                           0.14.0
# fonttools                        4.41.1
# frozendict                       2.3.8
# frozenlist                       1.4.0
# fsspec                           2023.6.0
# future                           0.18.3
# gast                             0.4.0
# gcsfs                            2023.6.0
# gdown                            4.6.6
# gensim                           4.3.1
# geographiclib                    2.0
# geopandas                        0.13.2
# geopy                            2.3.0
# gin-config                       0.5.0
# glob2                            0.7
# google                           2.0.3
# google-api-core                  2.11.1
# google-api-python-client         2.84.0
# google-auth                      2.17.3
# google-auth-httplib2             0.1.0
# google-auth-oauthlib             1.0.0
# google-cloud-bigquery            3.10.0
# google-cloud-bigquery-connection 1.12.1
# google-cloud-bigquery-storage    2.22.0
# google-cloud-core                2.3.3
# google-cloud-datastore           2.15.2
# google-cloud-firestore           2.11.1
# google-cloud-functions           1.13.1
# google-cloud-language            2.9.1
# google-cloud-storage             2.8.0
# google-cloud-translate           3.11.2
# google-crc32c                    1.5.0
# google-pasta                     0.2.0
# google-resumable-media           2.5.0
# googleapis-common-protos         1.59.1
# googledrivedownloader            0.4
# graphviz                         0.20.1
# greenlet                         2.0.2
# grpc-google-iam-v1               0.12.6
# grpcio                           1.56.2
# grpcio-status                    1.48.2
# gspread                          3.4.2
# gspread-dataframe                3.3.1
# gym                              0.25.2
# gym-notices                      0.0.8
# h5netcdf                         1.2.0
# h5py                             3.8.0
# holidays                         0.29
# holoviews                        1.15.4
# html5lib                         1.1
# httpimport                       1.3.1
# httplib2                         0.21.0
# humanize                         4.6.0
# hyperopt                         0.2.7
# idna                             3.4
# imageio                          2.25.1
# imageio-ffmpeg                   0.4.8
# imagesize                        1.4.1
# imbalanced-learn                 0.10.1
# imgaug                           0.4.0
# importlib-metadata               4.6.4
# importlib-resources              6.0.0
# imutils                          0.5.4
# inflect                          6.0.5
# iniconfig                        2.0.0
# intel-openmp                     2023.2.0
# ipykernel                        5.5.6
# ipython                          7.34.0
# ipython-genutils                 0.2.0
# ipython-sql                      0.4.1
# ipywidgets                       7.7.1
# itsdangerous                     2.1.2
# jax                              0.4.14
# jaxlib                           0.4.14
# jedi                             0.19.0
# jeepney                          0.7.1
# jieba                            0.42.1
# Jinja2                           3.1.2
# joblib                           1.3.1
# jsonpickle                       3.0.1
# jsonschema                       4.3.3
# jupyter                          1.0.0
# jupyter-client                   6.1.12
# jupyter-console                  6.1.0
# jupyter_core                     5.3.1
# jupyter-server                   1.24.0
# jupyterlab-pygments              0.2.2
# jupyterlab-widgets               3.0.8
# kaggle                           1.5.16
# keras                            2.12.0
# keyring                          23.5.0
# kiwisolver                       1.4.4
# langcodes                        3.3.0
# launchpadlib                     1.10.16
# lazr.restfulclient               0.14.4
# lazr.uri                         1.0.6
# lazy_loader                      0.3
# libclang                         16.0.6
# librosa                          0.10.0.post2
# lightgbm                         3.3.5
# linkify-it-py                    2.0.2
# lit                              16.0.6
# llvmlite                         0.39.1
# locket                           1.0.0
# logical-unification              0.4.6
# LunarCalendar                    0.0.9
# lxml                             4.9.3
# Markdown                         3.4.4
# markdown-it-py                   3.0.0
# MarkupSafe                       2.1.3
# matplotlib                       3.7.1
# matplotlib-inline                0.1.6
# matplotlib-venn                  0.11.9
# mdit-py-plugins                  0.4.0
# mdurl                            0.1.2
# miniKanren                       1.0.3
# missingno                        0.5.2
# mistune                          0.8.4
# mizani                           0.8.1
# mkl                              2019.0
# ml-dtypes                        0.2.0
# mlxtend                          0.22.0
# more-itertools                   9.1.0
# moviepy                          1.0.3
# mpmath                           1.3.0
# msgpack                          1.0.5
# multidict                        6.0.4
# multipledispatch                 1.0.0
# multitasking                     0.0.11
# murmurhash                       1.0.9
# music21                          8.1.0
# natsort                          8.3.1
# nbclient                         0.8.0
# nbconvert                        6.5.4
# nbformat                         5.9.1
# nest-asyncio                     1.5.6
# networkx                         3.1
# nibabel                          3.0.2
# nltk                             3.8.1
# notebook                         6.4.8
# numba                            0.56.4
# numexpr                          2.8.4
# numpy                            1.22.4
# oauth2client                     4.1.3
# oauthlib                         3.2.2
# opencv-contrib-python            4.7.0.72
# opencv-python                    4.8.0.74
# opencv-python-headless           4.8.0.74
# openpyxl                         3.0.10
# opt-einsum                       3.3.0
# optax                            0.1.5
# orbax-checkpoint                 0.3.0
# osqp                             0.6.2.post8
# packaging                        23.1
# palettable                       3.3.3
# pandas                           1.5.3
# pandas-datareader                0.10.0
# pandas-gbq                       0.17.9
# pandocfilters                    1.5.0
# panel                            1.2.0
# param                            1.13.0
# parso                            0.8.3
# partd                            1.4.0
# pathlib                          1.0.1
# pathy                            0.10.2
# patsy                            0.5.3
# pexpect                          4.8.0
# pickleshare                      0.7.5
# Pillow                           9.4.0
# pip                              23.2.1
# pip-tools                        6.13.0
# platformdirs                     3.9.1
# plotly                           5.13.1
# plotnine                         0.10.1
# pluggy                           1.2.0
# polars                           0.17.3
# pooch                            1.6.0
# portpicker                       1.5.2
# prefetch-generator               1.0.3
# preshed                          3.0.8
# prettytable                      0.7.2
# proglog                          0.1.10
# progressbar2                     4.2.0
# prometheus-client                0.17.1
# promise                          2.3
# prompt-toolkit                   3.0.39
# prophet                          1.1.4
# proto-plus                       1.22.3
# protobuf                         3.20.3
# psutil                           5.9.5
# psycopg2                         2.9.6
# ptyprocess                       0.7.0
# py-cpuinfo                       9.0.0
# py4j                             0.10.9.7
# pyarrow                          9.0.0
# pyasn1                           0.5.0
# pyasn1-modules                   0.3.0
# pycocotools                      2.0.6
# pycparser                        2.21
# pyct                             0.5.0
# pydantic                         1.10.12
# pydata-google-auth               1.8.1
# pydot                            1.4.2
# pydot-ng                         2.0.0
# pydotplus                        2.0.2
# PyDrive                          1.3.1
# pyerfa                           2.0.0.3
# pygame                           2.5.0
# Pygments                         2.14.0
# PyJWT                            2.3.0
# pymc                             5.1.2
# PyMeeus                          0.5.12
# pymystem3                        0.2.0
# PyOpenGL                         3.1.7
# pyparsing                        3.1.0
# pyproj                           3.6.0
# pyproject_hooks                  1.0.0
# pyrsistent                       0.19.3
# PySocks                          1.7.1
# pytensor                         2.10.1
# pytest                           7.2.2
# python-dateutil                  2.8.2
# python-louvain                   0.16
# python-slugify                   8.0.1
# python-utils                     3.7.0
# pytz                             2022.7.1
# pyviz-comms                      2.3.2
# PyWavelets                       1.4.1
# pywin32                          306
# pywin32-ctypes                   0.2.2
# pywinpty                         2.0.11
# PyYAML                           6.0.1
# pyzmq                            23.2.1
# qdldl                            0.1.7.post0
# qtconsole                        5.4.3
# QtPy                             2.3.1
# qudida                           0.0.4
# regex                            2022.10.31
# requests                         2.27.1
# requests-oauthlib                1.3.1
# requirements-parser              0.5.0
# rich                             13.4.2
# rsa                              4.9
# scikit-image                     0.19.3
# scikit-learn                     1.2.2
# scipy                            1.10.1
# scs                              3.2.3
# seaborn                          0.12.2
# SecretStorage                    3.3.1
# Send2Trash                       1.8.2
# setuptools                       68.0.0
# shapely                          2.0.1
# six                              1.16.0
# sklearn-pandas                   2.2.0
# smart-open                       6.3.0
# sniffio                          1.3.0
# snowballstemmer                  2.2.0
# sortedcontainers                 2.4.0
# soundfile                        0.12.1
# soupsieve                        2.4.1
# soxr                             0.3.5
# spacy                            3.5.4
# spacy-legacy                     3.0.12
# spacy-loggers                    1.0.4
# Sphinx                           3.5.4
# sphinxcontrib-applehelp          1.0.4
# sphinxcontrib-devhelp            1.0.2
# sphinxcontrib-htmlhelp           2.0.1
# sphinxcontrib-jsmath             1.0.1
# sphinxcontrib-qthelp             1.0.3
# sphinxcontrib-serializinghtml    1.1.5
# SQLAlchemy                       2.0.19
# sqlparse                         0.4.4
# srsly                            2.4.7
# statsmodels                      0.13.5
# sympy                            1.11.1
# tables                           3.8.0
# tabulate                         0.9.0
# tblib                            2.0.0
# tenacity                         8.2.2
# tensorboard                      2.12.3
# tensorboard-data-server          0.7.1
# tensorflow                       2.12.0
# tensorflow-addons                0.21.0
# tensorflow-estimator             2.12.0
# tensorflow-intel                 2.12.0
# tensorflow-io-gcs-filesystem     0.31.0
# tensorflow-probability           0.20.1
# tensorstore                      0.1.40
# termcolor                        2.3.0
# terminado                        0.17.1
# text-unidecode                   1.3
# textblob                         0.17.1
# tf-slim                          1.1.0
# thinc                            8.1.10
# threadpoolctl                    3.2.0
# tifffile                         2023.7.18
# tinycss2                         1.2.1
# toml                             0.10.2
# tomli                            2.0.1
# toolz                            0.12.0
# torch                            2.0.1
# torchvision                      0.15.2
# tornado                          6.3.1
# tqdm                             4.65.0
# traitlets                        5.7.1
# tweepy                           4.13.0
# typeguard                        2.13.3
# typer                            0.9.0
# types-setuptools                 68.0.0.3
# typing_extensions                4.7.1
# tzdata                           2023.3
# tzlocal                          5.0.1
# uc-micro-py                      1.0.2
# uritemplate                      4.1.1
# urllib3                          1.26.16
# vega-datasets                    0.9.0
# wadllib                          1.3.6
# wasabi                           1.1.2
# wcwidth                          0.2.6
# webcolors                        1.13
# webencodings                     0.5.1
# websocket-client                 1.6.1
# Werkzeug                         2.3.6
# wheel                            0.40.0
# widgetsnbextension               3.6.4
# wordcloud                        1.8.2.2
# wrapt                            1.14.1
# xarray                           2022.12.0
# xarray-einstats                  0.6.0
# xgboost                          1.7.6
# xlrd                             2.0.1
# xyzservices                      2023.7.0
# yarl                             1.9.2
# yellowbrick                      1.5
# yfinance                         0.2.25
# zict                             3.0.0
# zipp                             3.16.2

# %%
import tensorflow as tf
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
from tensorflow.keras import layers
import tensorflow_addons as tfa
import matplotlib.pyplot as plt
import numpy as np
import cv2
import os
import scipy.io
import shutil
# Out:
# C:\Users\EaglesonLabs\Anaconda2\envs\vit-object-detection\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
import pathlib, os, random
data_dir = pathlib.Path("obj/").with_suffix('')
image_files = list(data_dir.glob('*.jpg'))
print(len(image_files))

def list_files(full_data_path = "obj/", image_ext = '.jpg'):

    files = []

    discarded = 0
    masked_instance = 0

    for r, d, f in os.walk(full_data_path):
        for file in f:
            if file.endswith(".txt"):

                # first, let's check if there is only one object
                with open(full_data_path + "/" + file, 'r') as fp: 
                    lines = fp.readlines()
                    if len(lines) > 1:
                        discarded += 1
                        continue
                    

                strip = file[0:len(file) - len(".txt")]  
                # secondly, check if the paired image actually exist
                image_path = full_data_path + "/" + strip + image_ext
                if os.path.isfile(image_path):
                    # checking the class. '0' means masked, '1' for unmasked
                    if lines[0][0] == '0':
                        masked_instance += 1
                    files.append(strip)

    size = len(files)   
    print(str(discarded) + " file(s) discarded")
    print(str(size) + " valid case(s)")
    print(str(masked_instance) + " are masked cases")
    random.shuffle(files)
    return files

files = list_files()
# Out:
# 1510
# 218 file(s) discarded
# 1292 valid case(s)
# 832 are masked cases

# %%
def read_yolo_annotation_file(file_path):
    with open(file_path, 'r') as f:
        lines = f.readlines()

    annotations = []
    for line in lines:
        parts = line.strip().split(' ')
        object_class = int(parts[0])
        x_center, y_center, width, height = map(float, parts[1:])
        annotations.append((object_class, x_center, y_center, width, height))

    return annotations

# %%
image_size = 224  # resize input images to this size
num_classes = 2 # the number of classes in the dataset
images, targets, classes = [], [], []

# loop over the annotations and images, preprocess them and store in lists
for file in files:
    # load the x,y,w,h of the bounding box here as top_left_x/y & bottom_right_x/y
    annotations = read_yolo_annotation_file('obj/' + file + '.txt')
    class_prediction = annotations[0][0]
    top_left_x = annotations[0][1]
    top_left_y = annotations[0][2]
    bottom_right_x = annotations[0][3]
    bottom_right_y = annotations[0][4]
    
    # load the actual image here
    image = keras.utils.load_img("obj/" + file + '.jpg',)
    image = image.resize((image_size, image_size))
    
    # convert image to array and append to list
    images.append(keras.utils.img_to_array(image))
    # apply relative scaling to bounding boxes as per given image and append to list
    targets.append(
        (
            float(top_left_x),
            float(top_left_y),
            float(bottom_right_x),
            float(bottom_right_y),
        )
    )
    classes.append(to_categorical(class_prediction, num_classes))



# Convert the list to numpy array, split to train and test dataset
(x_train), (bounding_boxes_y_train), (class_labels_y_train) = (
    np.asarray(images[:int( 0.8  *len(images))],dtype=object),
    np.asarray(targets[:int(0.8 * len(targets))],dtype=object),
    np.asarray(classes[:int(0.8 * len(classes))],dtype=object),
)

(x_test), (bounding_boxes_y_test), (class_labels_y_test) = (
    np.asarray(images[int(0.8 * len(images)):],dtype=object),
    np.asarray(targets[int(0.8 * len(targets)):],dtype=object),
    np.asarray(classes[int(0.8 * len(classes)):],dtype=object),
)

x_train = tf.convert_to_tensor(x_train, dtype=tf.float32)
bounding_boxes_y_train = tf.convert_to_tensor(bounding_boxes_y_train, dtype=tf.float32)
class_labels_y_train = tf.convert_to_tensor(class_labels_y_train, dtype=tf.float32)
x_test = tf.convert_to_tensor(x_test, dtype=tf.float32)
bounding_boxes_y_test = tf.convert_to_tensor(bounding_boxes_y_test, dtype=tf.float32)
class_labels_y_test = tf.convert_to_tensor(class_labels_y_test, dtype=tf.float32)

# %%
num = 0

image = x_train[num].numpy().astype("uint8")



bounding_box = bounding_boxes_y_train[num].numpy()
label = np.argmax(class_labels_y_train[num].numpy())
print('bounding_box: ', bounding_box)
print('label: ', label)

x_center, y_center = bounding_box[0] * image_size,  bounding_box[1] * image_size
width, height = bounding_box[2] * image_size,  bounding_box[3] * image_size

# Calculate x_min, y_min, x_max, and y_max based on the center coordinates, width/heigth and input size
x_min = int(x_center - (width / 2))
y_min = int( y_center - (height / 2))
x_max = x_min + int(width)
y_max = y_min + int(height)

top_left = (x_min, y_min)
bottom_right = (x_max, y_max)

# Convert image to RGB if it's grayscale
image = np.squeeze(image)  # Remove the extra batch dimension
if len(image.shape) == 2:
    image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)
# Draw rectangles
cv2.rectangle(image, top_left, bottom_right, (255,0,0), 2)
plt.figure(figsize=(4, 4))
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# [0.42553192 0.6236749  0.7446808  0.5759717 ]
# 0

# %%
architecture_id = 'base architecture + custom dataset'

# %%
def mlp(x, hidden_units, dropout_rate):
    for units in hidden_units:
        x = layers.Dense(units, activation=tf.nn.gelu)(x)
        x = layers.Dropout(dropout_rate)(x)
    return x

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super().__init__()
        self.patch_size = patch_size

    #     Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        # return patches
        return tf.reshape(patches, [batch_size, -1, patches.shape[-1]])

# %%
import matplotlib.pyplot as plt

patch_size = 32  # Size of the patches to be extracted from the input images

# Convert the EagerTensor to a NumPy array
x_train_numpy = x_train[0].numpy().astype("uint8")

plt.figure(figsize=(4, 4))
plt.imshow(x_train_numpy)
plt.axis("off")
plt.show()

patches = Patches(patch_size)(tf.convert_to_tensor([x_train_numpy]))
print(f"Image size: {image_size} X {image_size}")
print(f"Patch size: {patch_size} X {patch_size}")
print(f"{patches.shape[1]} patches per image \n{patches.shape[-1]} elements per patch")

n = int(np.sqrt(patches.shape[1]))
plt.figure(figsize=(4, 4))
for i, patch in enumerate(patches[0]):
    ax = plt.subplot(n, n, i + 1)
    patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
    plt.imshow(patch_img.numpy().astype("uint8"))
    plt.axis("off")
# Out:
# Image size: 224 X 224
# Patch size: 32 X 32
# 49 patches per image
# 3072 elements per patch

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super().__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    # Override function to avoid error while saving model
    def get_config(self):
        config = super().get_config().copy()
        config.update(
            {
                "input_shape": input_shape,
                "patch_size": patch_size,
                "num_patches": num_patches,
                "projection_dim": projection_dim,
                "num_heads": num_heads,
                "transformer_units": transformer_units,
                "transformer_layers": transformer_layers,
                "mlp_head_units": mlp_head_units,
            }
        )
        return config

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
def create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
):
    inputs = layers.Input(shape=input_shape)
    # Create patches
    patches = Patches(patch_size)(inputs)
    # Encode patches
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    # Create multiple layers of the Transformer block.
    for _ in range(transformer_layers):
        # Layer normalization 1.
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        # Create a multi-head attention layer.
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=projection_dim, dropout=0.1
        )(x1, x1)
        # Skip connection 1.
        x2 = layers.Add()([attention_output, encoded_patches])
        # Layer normalization 2.
        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        # MLP
        x3 = mlp(x3, hidden_units=transformer_units, dropout_rate=0.1)
        # Skip connection 2.
        encoded_patches = layers.Add()([x3, x2])

    # Create a [batch_size, projection_dim] tensor.
    representation = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
    representation = layers.Flatten()(representation)
    representation = layers.Dropout(0.3)(representation)
    # Add MLP.
    features = mlp(representation, hidden_units=mlp_head_units, dropout_rate=0.3)

    # Final MLP head for bounding box prediction
    bounding_box = layers.Dense(4, name='bounding_box')(features)

    # Final dense layer for class prediction
    class_predictions = layers.Dense(num_classes, activation='softmax', name='class_predictions')(features)

    # Keras model with both bounding box and class predictions
    model = keras.Model(inputs=inputs, outputs=[bounding_box, class_predictions])

    # return model.
    return model

# %%
def calculate_iou(y_true, y_pred):
    intersection = tf.reduce_sum(tf.minimum(y_true, y_pred))
    union = tf.reduce_sum(tf.maximum(y_true, y_pred))
    return intersection / union

# %%
folder_count = 0  # type: int
input_path = "vit-model performance"  # type: str
for folders in os.listdir(input_path):  # loop over all files
    if os.path.isdir(os.path.join(input_path, folders)):  # if it's a directory
        folder_count += 1  # increment counter
new_folder = os.path.join(input_path, 'model '+ str(folder_count) + ' - ' + architecture_id)
os.mkdir(new_folder)

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import Image, display
def run_experiment(model, learning_rate, weight_decay, batch_size, num_epochs):

    optimizer = tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    )
    
    # Compile the model with appropriate loss functions
    model.compile(
        optimizer='adam',
        loss={'bounding_box': 'mse', 'class_predictions': 'binary_crossentropy'},
        metrics = {'class_predictions' : 'accuracy', 'bounding_box' : calculate_iou }
    )
    
    # Train the model using both bounding_boxes_y and class_labels_y as y-values.
    history = model.fit(
        x = x_train,    # Your training image data
        y = {'bounding_box': bounding_boxes_y_train, 'class_predictions': class_labels_y_train},
        batch_size=batch_size,
        epochs=num_epochs,
        validation_split=0.1,
        callbacks=[
            keras.callbacks.EarlyStopping(monitor="val_loss", patience=30),
        ],
    )
    
    dot_img_file = os.path.join(new_folder, 'architecture.png')
    tf.keras.utils.plot_model(model, to_file=dot_img_file, show_shapes=True)
    display(Image(dot_img_file))
    return history, model



input_shape = (image_size, image_size, 3)  # input image shape
learning_rate = 0.001
weight_decay = 0.0001
batch_size = 32
num_epochs = 100
projection_dim = 8
num_heads = 4
# Size of the transformer layers
transformer_units = [
    projection_dim * 2,
    projection_dim,
]
transformer_layers = 4
mlp_head_units = [512, 64, 32]  # Size of the dense layers


history = []
num_patches = (image_size // patch_size) ** 2

vit_object_detector = create_vit_object_detector(
    input_shape,
    patch_size,
    num_patches,
    projection_dim,
    num_heads,
    transformer_units,
    transformer_layers,
    mlp_head_units,
)

# Train model
history, model = run_experiment(
    vit_object_detector, learning_rate, weight_decay, batch_size, num_epochs
)
# Out:
# Epoch 1/100
# 30/30 [==============================] - 8s 68ms/step - loss: 1.0188 - bounding_box_loss: 0.3133 - class_predictions_loss: 0.7055 - bounding_box_calculate_iou: 0.2780 - class_predictions_accuracy: 0.5748 - val_loss: 0.7878 - val_bounding_box_loss: 0.1230 - val_class_predictions_loss: 0.6648 - val_bounding_box_calculate_iou: 0.3641 - val_class_predictions_accuracy: 0.6635
# Epoch 2/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.8288 - bounding_box_loss: 0.1639 - class_predictions_loss: 0.6649 - bounding_box_calculate_iou: 0.4124 - class_predictions_accuracy: 0.6157 - val_loss: 0.7454 - val_bounding_box_loss: 0.0844 - val_class_predictions_loss: 0.6610 - val_bounding_box_calculate_iou: 0.4860 - val_class_predictions_accuracy: 0.6635
# Epoch 3/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.7970 - bounding_box_loss: 0.1221 - class_predictions_loss: 0.6749 - bounding_box_calculate_iou: 0.4741 - class_predictions_accuracy: 0.6125 - val_loss: 0.6704 - val_bounding_box_loss: 0.0248 - val_class_predictions_loss: 0.6455 - val_bounding_box_calculate_iou: 0.7769 - val_class_predictions_accuracy: 0.6635
# Epoch 4/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.7523 - bounding_box_loss: 0.0793 - class_predictions_loss: 0.6730 - bounding_box_calculate_iou: 0.5962 - class_predictions_accuracy: 0.6372 - val_loss: 0.6714 - val_bounding_box_loss: 0.0232 - val_class_predictions_loss: 0.6482 - val_bounding_box_calculate_iou: 0.7873 - val_class_predictions_accuracy: 0.6635
# Epoch 5/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.7226 - bounding_box_loss: 0.0618 - class_predictions_loss: 0.6608 - bounding_box_calculate_iou: 0.6550 - class_predictions_accuracy: 0.6459 - val_loss: 0.6649 - val_bounding_box_loss: 0.0194 - val_class_predictions_loss: 0.6455 - val_bounding_box_calculate_iou: 0.8205 - val_class_predictions_accuracy: 0.6635
# Epoch 6/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.7065 - bounding_box_loss: 0.0451 - class_predictions_loss: 0.6614 - bounding_box_calculate_iou: 0.7003 - class_predictions_accuracy: 0.6416 - val_loss: 0.6630 - val_bounding_box_loss: 0.0194 - val_class_predictions_loss: 0.6436 - val_bounding_box_calculate_iou: 0.8311 - val_class_predictions_accuracy: 0.6635
# Epoch 7/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.7095 - bounding_box_loss: 0.0411 - class_predictions_loss: 0.6684 - bounding_box_calculate_iou: 0.7150 - class_predictions_accuracy: 0.6394 - val_loss: 0.6654 - val_bounding_box_loss: 0.0190 - val_class_predictions_loss: 0.6464 - val_bounding_box_calculate_iou: 0.8298 - val_class_predictions_accuracy: 0.6635
# Epoch 8/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6986 - bounding_box_loss: 0.0383 - class_predictions_loss: 0.6603 - bounding_box_calculate_iou: 0.7327 - class_predictions_accuracy: 0.6416 - val_loss: 0.6609 - val_bounding_box_loss: 0.0181 - val_class_predictions_loss: 0.6428 - val_bounding_box_calculate_iou: 0.8339 - val_class_predictions_accuracy: 0.6635
# Epoch 9/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6897 - bounding_box_loss: 0.0336 - class_predictions_loss: 0.6561 - bounding_box_calculate_iou: 0.7512 - class_predictions_accuracy: 0.6405 - val_loss: 0.6592 - val_bounding_box_loss: 0.0180 - val_class_predictions_loss: 0.6411 - val_bounding_box_calculate_iou: 0.8204 - val_class_predictions_accuracy: 0.6635
# Epoch 10/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6891 - bounding_box_loss: 0.0347 - class_predictions_loss: 0.6544 - bounding_box_calculate_iou: 0.7360 - class_predictions_accuracy: 0.6405 - val_loss: 0.6595 - val_bounding_box_loss: 0.0179 - val_class_predictions_loss: 0.6416 - val_bounding_box_calculate_iou: 0.8232 - val_class_predictions_accuracy: 0.6635
# Epoch 11/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6898 - bounding_box_loss: 0.0326 - class_predictions_loss: 0.6572 - bounding_box_calculate_iou: 0.7466 - class_predictions_accuracy: 0.6416 - val_loss: 0.6608 - val_bounding_box_loss: 0.0197 - val_class_predictions_loss: 0.6411 - val_bounding_box_calculate_iou: 0.8042 - val_class_predictions_accuracy: 0.6635
# Epoch 12/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6861 - bounding_box_loss: 0.0303 - class_predictions_loss: 0.6557 - bounding_box_calculate_iou: 0.7645 - class_predictions_accuracy: 0.6416 - val_loss: 0.6689 - val_bounding_box_loss: 0.0223 - val_class_predictions_loss: 0.6466 - val_bounding_box_calculate_iou: 0.7783 - val_class_predictions_accuracy: 0.6635
# Epoch 13/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.6863 - bounding_box_loss: 0.0298 - class_predictions_loss: 0.6565 - bounding_box_calculate_iou: 0.7589 - class_predictions_accuracy: 0.6416 - val_loss: 0.6591 - val_bounding_box_loss: 0.0189 - val_class_predictions_loss: 0.6402 - val_bounding_box_calculate_iou: 0.8307 - val_class_predictions_accuracy: 0.6635
# Epoch 14/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6836 - bounding_box_loss: 0.0282 - class_predictions_loss: 0.6554 - bounding_box_calculate_iou: 0.7750 - class_predictions_accuracy: 0.6416 - val_loss: 0.6577 - val_bounding_box_loss: 0.0184 - val_class_predictions_loss: 0.6393 - val_bounding_box_calculate_iou: 0.8301 - val_class_predictions_accuracy: 0.6635
# Epoch 15/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6809 - bounding_box_loss: 0.0277 - class_predictions_loss: 0.6532 - bounding_box_calculate_iou: 0.7716 - class_predictions_accuracy: 0.6426 - val_loss: 0.6587 - val_bounding_box_loss: 0.0191 - val_class_predictions_loss: 0.6395 - val_bounding_box_calculate_iou: 0.8140 - val_class_predictions_accuracy: 0.6635
# Epoch 16/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6794 - bounding_box_loss: 0.0265 - class_predictions_loss: 0.6530 - bounding_box_calculate_iou: 0.7777 - class_predictions_accuracy: 0.6416 - val_loss: 0.6587 - val_bounding_box_loss: 0.0211 - val_class_predictions_loss: 0.6376 - val_bounding_box_calculate_iou: 0.7963 - val_class_predictions_accuracy: 0.6635
# Epoch 17/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.6773 - bounding_box_loss: 0.0272 - class_predictions_loss: 0.6501 - bounding_box_calculate_iou: 0.7674 - class_predictions_accuracy: 0.6416 - val_loss: 0.6556 - val_bounding_box_loss: 0.0186 - val_class_predictions_loss: 0.6371 - val_bounding_box_calculate_iou: 0.8265 - val_class_predictions_accuracy: 0.6635
# Epoch 18/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6737 - bounding_box_loss: 0.0241 - class_predictions_loss: 0.6497 - bounding_box_calculate_iou: 0.7823 - class_predictions_accuracy: 0.6416 - val_loss: 0.6545 - val_bounding_box_loss: 0.0187 - val_class_predictions_loss: 0.6358 - val_bounding_box_calculate_iou: 0.8240 - val_class_predictions_accuracy: 0.6635
# Epoch 19/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.6728 - bounding_box_loss: 0.0248 - class_predictions_loss: 0.6480 - bounding_box_calculate_iou: 0.7822 - class_predictions_accuracy: 0.6416 - val_loss: 0.6515 - val_bounding_box_loss: 0.0190 - val_class_predictions_loss: 0.6325 - val_bounding_box_calculate_iou: 0.8213 - val_class_predictions_accuracy: 0.6635
# Epoch 20/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.6768 - bounding_box_loss: 0.0243 - class_predictions_loss: 0.6525 - bounding_box_calculate_iou: 0.7866 - class_predictions_accuracy: 0.6416 - val_loss: 0.6535 - val_bounding_box_loss: 0.0201 - val_class_predictions_loss: 0.6334 - val_bounding_box_calculate_iou: 0.8077 - val_class_predictions_accuracy: 0.6635
# Epoch 21/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6628 - bounding_box_loss: 0.0276 - class_predictions_loss: 0.6352 - bounding_box_calculate_iou: 0.7841 - class_predictions_accuracy: 0.6416 - val_loss: 0.6303 - val_bounding_box_loss: 0.0234 - val_class_predictions_loss: 0.6069 - val_bounding_box_calculate_iou: 0.7998 - val_class_predictions_accuracy: 0.6635
# Epoch 22/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6486 - bounding_box_loss: 0.0294 - class_predictions_loss: 0.6192 - bounding_box_calculate_iou: 0.7719 - class_predictions_accuracy: 0.6416 - val_loss: 0.6057 - val_bounding_box_loss: 0.0310 - val_class_predictions_loss: 0.5747 - val_bounding_box_calculate_iou: 0.7683 - val_class_predictions_accuracy: 0.6635
# Epoch 23/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.6306 - bounding_box_loss: 0.0330 - class_predictions_loss: 0.5975 - bounding_box_calculate_iou: 0.7468 - class_predictions_accuracy: 0.6416 - val_loss: 0.5762 - val_bounding_box_loss: 0.0306 - val_class_predictions_loss: 0.5456 - val_bounding_box_calculate_iou: 0.7598 - val_class_predictions_accuracy: 0.6635
# Epoch 24/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.5907 - bounding_box_loss: 0.0362 - class_predictions_loss: 0.5545 - bounding_box_calculate_iou: 0.7322 - class_predictions_accuracy: 0.6416 - val_loss: 0.5228 - val_bounding_box_loss: 0.0292 - val_class_predictions_loss: 0.4936 - val_bounding_box_calculate_iou: 0.7637 - val_class_predictions_accuracy: 0.6635
# Epoch 25/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.5716 - bounding_box_loss: 0.0419 - class_predictions_loss: 0.5297 - bounding_box_calculate_iou: 0.7227 - class_predictions_accuracy: 0.6416 - val_loss: 0.5064 - val_bounding_box_loss: 0.0260 - val_class_predictions_loss: 0.4805 - val_bounding_box_calculate_iou: 0.7753 - val_class_predictions_accuracy: 0.6635
# Epoch 26/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.5350 - bounding_box_loss: 0.0410 - class_predictions_loss: 0.4939 - bounding_box_calculate_iou: 0.7239 - class_predictions_accuracy: 0.6372 - val_loss: 0.4713 - val_bounding_box_loss: 0.0225 - val_class_predictions_loss: 0.4488 - val_bounding_box_calculate_iou: 0.7972 - val_class_predictions_accuracy: 0.6635
# Epoch 27/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.5066 - bounding_box_loss: 0.0408 - class_predictions_loss: 0.4659 - bounding_box_calculate_iou: 0.7344 - class_predictions_accuracy: 0.6609 - val_loss: 0.4408 - val_bounding_box_loss: 0.0195 - val_class_predictions_loss: 0.4213 - val_bounding_box_calculate_iou: 0.8157 - val_class_predictions_accuracy: 0.7692
# Epoch 28/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.4839 - bounding_box_loss: 0.0372 - class_predictions_loss: 0.4467 - bounding_box_calculate_iou: 0.7525 - class_predictions_accuracy: 0.7793 - val_loss: 0.4067 - val_bounding_box_loss: 0.0188 - val_class_predictions_loss: 0.3880 - val_bounding_box_calculate_iou: 0.8202 - val_class_predictions_accuracy: 0.8750
# Epoch 29/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.4215 - bounding_box_loss: 0.0373 - class_predictions_loss: 0.3842 - bounding_box_calculate_iou: 0.7490 - class_predictions_accuracy: 0.8622 - val_loss: 0.4458 - val_bounding_box_loss: 0.0175 - val_class_predictions_loss: 0.4283 - val_bounding_box_calculate_iou: 0.8280 - val_class_predictions_accuracy: 0.8558
# Epoch 30/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.3941 - bounding_box_loss: 0.0340 - class_predictions_loss: 0.3601 - bounding_box_calculate_iou: 0.7583 - class_predictions_accuracy: 0.8956 - val_loss: 0.3816 - val_bounding_box_loss: 0.0171 - val_class_predictions_loss: 0.3645 - val_bounding_box_calculate_iou: 0.8333 - val_class_predictions_accuracy: 0.8750
# Epoch 31/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.3773 - bounding_box_loss: 0.0356 - class_predictions_loss: 0.3417 - bounding_box_calculate_iou: 0.7598 - class_predictions_accuracy: 0.8794 - val_loss: 0.4657 - val_bounding_box_loss: 0.0173 - val_class_predictions_loss: 0.4484 - val_bounding_box_calculate_iou: 0.8309 - val_class_predictions_accuracy: 0.8558
# Epoch 32/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.3774 - bounding_box_loss: 0.0301 - class_predictions_loss: 0.3473 - bounding_box_calculate_iou: 0.7675 - class_predictions_accuracy: 0.8881 - val_loss: 0.3460 - val_bounding_box_loss: 0.0171 - val_class_predictions_loss: 0.3289 - val_bounding_box_calculate_iou: 0.8301 - val_class_predictions_accuracy: 0.8750
# Epoch 33/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.3422 - bounding_box_loss: 0.0288 - class_predictions_loss: 0.3134 - bounding_box_calculate_iou: 0.7765 - class_predictions_accuracy: 0.8881 - val_loss: 0.3580 - val_bounding_box_loss: 0.0167 - val_class_predictions_loss: 0.3413 - val_bounding_box_calculate_iou: 0.8381 - val_class_predictions_accuracy: 0.8750
# Epoch 34/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.3291 - bounding_box_loss: 0.0282 - class_predictions_loss: 0.3009 - bounding_box_calculate_iou: 0.7772 - class_predictions_accuracy: 0.8913 - val_loss: 0.3471 - val_bounding_box_loss: 0.0174 - val_class_predictions_loss: 0.3297 - val_bounding_box_calculate_iou: 0.8253 - val_class_predictions_accuracy: 0.8750
# Epoch 35/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2987 - bounding_box_loss: 0.0279 - class_predictions_loss: 0.2708 - bounding_box_calculate_iou: 0.7743 - class_predictions_accuracy: 0.9107 - val_loss: 0.3569 - val_bounding_box_loss: 0.0171 - val_class_predictions_loss: 0.3398 - val_bounding_box_calculate_iou: 0.8324 - val_class_predictions_accuracy: 0.8942
# Epoch 36/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.3067 - bounding_box_loss: 0.0268 - class_predictions_loss: 0.2799 - bounding_box_calculate_iou: 0.7813 - class_predictions_accuracy: 0.8967 - val_loss: 0.3674 - val_bounding_box_loss: 0.0165 - val_class_predictions_loss: 0.3509 - val_bounding_box_calculate_iou: 0.8338 - val_class_predictions_accuracy: 0.8942
# Epoch 37/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2814 - bounding_box_loss: 0.0259 - class_predictions_loss: 0.2555 - bounding_box_calculate_iou: 0.7854 - class_predictions_accuracy: 0.9182 - val_loss: 0.3553 - val_bounding_box_loss: 0.0162 - val_class_predictions_loss: 0.3391 - val_bounding_box_calculate_iou: 0.8394 - val_class_predictions_accuracy: 0.8942
# Epoch 38/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2541 - bounding_box_loss: 0.0253 - class_predictions_loss: 0.2288 - bounding_box_calculate_iou: 0.7898 - class_predictions_accuracy: 0.9214 - val_loss: 0.3487 - val_bounding_box_loss: 0.0160 - val_class_predictions_loss: 0.3327 - val_bounding_box_calculate_iou: 0.8393 - val_class_predictions_accuracy: 0.8654
# Epoch 39/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2737 - bounding_box_loss: 0.0243 - class_predictions_loss: 0.2494 - bounding_box_calculate_iou: 0.7966 - class_predictions_accuracy: 0.9085 - val_loss: 0.3673 - val_bounding_box_loss: 0.0158 - val_class_predictions_loss: 0.3515 - val_bounding_box_calculate_iou: 0.8396 - val_class_predictions_accuracy: 0.8846
# Epoch 40/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2760 - bounding_box_loss: 0.0243 - class_predictions_loss: 0.2517 - bounding_box_calculate_iou: 0.7901 - class_predictions_accuracy: 0.9064 - val_loss: 0.3511 - val_bounding_box_loss: 0.0156 - val_class_predictions_loss: 0.3355 - val_bounding_box_calculate_iou: 0.8422 - val_class_predictions_accuracy: 0.8942
# Epoch 41/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2555 - bounding_box_loss: 0.0240 - class_predictions_loss: 0.2315 - bounding_box_calculate_iou: 0.7876 - class_predictions_accuracy: 0.9107 - val_loss: 0.3337 - val_bounding_box_loss: 0.0148 - val_class_predictions_loss: 0.3188 - val_bounding_box_calculate_iou: 0.8459 - val_class_predictions_accuracy: 0.8846
# Epoch 42/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2266 - bounding_box_loss: 0.0223 - class_predictions_loss: 0.2043 - bounding_box_calculate_iou: 0.7999 - class_predictions_accuracy: 0.9311 - val_loss: 0.3467 - val_bounding_box_loss: 0.0158 - val_class_predictions_loss: 0.3310 - val_bounding_box_calculate_iou: 0.8426 - val_class_predictions_accuracy: 0.8846
# Epoch 43/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2522 - bounding_box_loss: 0.0245 - class_predictions_loss: 0.2277 - bounding_box_calculate_iou: 0.7983 - class_predictions_accuracy: 0.9203 - val_loss: 0.3578 - val_bounding_box_loss: 0.0157 - val_class_predictions_loss: 0.3421 - val_bounding_box_calculate_iou: 0.8432 - val_class_predictions_accuracy: 0.9038
# Epoch 44/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2077 - bounding_box_loss: 0.0220 - class_predictions_loss: 0.1857 - bounding_box_calculate_iou: 0.7999 - class_predictions_accuracy: 0.9290 - val_loss: 0.3612 - val_bounding_box_loss: 0.0158 - val_class_predictions_loss: 0.3454 - val_bounding_box_calculate_iou: 0.8376 - val_class_predictions_accuracy: 0.8846
# Epoch 45/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1975 - bounding_box_loss: 0.0232 - class_predictions_loss: 0.1743 - bounding_box_calculate_iou: 0.7881 - class_predictions_accuracy: 0.9376 - val_loss: 0.4412 - val_bounding_box_loss: 0.0167 - val_class_predictions_loss: 0.4245 - val_bounding_box_calculate_iou: 0.8281 - val_class_predictions_accuracy: 0.8654
# Epoch 46/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2325 - bounding_box_loss: 0.0233 - class_predictions_loss: 0.2092 - bounding_box_calculate_iou: 0.7981 - class_predictions_accuracy: 0.9300 - val_loss: 0.3910 - val_bounding_box_loss: 0.0156 - val_class_predictions_loss: 0.3753 - val_bounding_box_calculate_iou: 0.8479 - val_class_predictions_accuracy: 0.8654
# Epoch 47/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.2016 - bounding_box_loss: 0.0218 - class_predictions_loss: 0.1797 - bounding_box_calculate_iou: 0.8059 - class_predictions_accuracy: 0.9333 - val_loss: 0.4303 - val_bounding_box_loss: 0.0162 - val_class_predictions_loss: 0.4140 - val_bounding_box_calculate_iou: 0.8394 - val_class_predictions_accuracy: 0.8846
# Epoch 48/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.2328 - bounding_box_loss: 0.0209 - class_predictions_loss: 0.2119 - bounding_box_calculate_iou: 0.8080 - class_predictions_accuracy: 0.9257 - val_loss: 0.4900 - val_bounding_box_loss: 0.0155 - val_class_predictions_loss: 0.4745 - val_bounding_box_calculate_iou: 0.8424 - val_class_predictions_accuracy: 0.8558
# Epoch 49/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1971 - bounding_box_loss: 0.0205 - class_predictions_loss: 0.1765 - bounding_box_calculate_iou: 0.8119 - class_predictions_accuracy: 0.9311 - val_loss: 0.4535 - val_bounding_box_loss: 0.0156 - val_class_predictions_loss: 0.4379 - val_bounding_box_calculate_iou: 0.8410 - val_class_predictions_accuracy: 0.8750
# Epoch 50/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.2128 - bounding_box_loss: 0.0212 - class_predictions_loss: 0.1916 - bounding_box_calculate_iou: 0.8082 - class_predictions_accuracy: 0.9354 - val_loss: 0.3949 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.3800 - val_bounding_box_calculate_iou: 0.8476 - val_class_predictions_accuracy: 0.8846
# Epoch 51/100
# 30/30 [==============================] - 2s 52ms/step - loss: 0.1665 - bounding_box_loss: 0.0195 - class_predictions_loss: 0.1471 - bounding_box_calculate_iou: 0.8174 - class_predictions_accuracy: 0.9386 - val_loss: 0.4224 - val_bounding_box_loss: 0.0152 - val_class_predictions_loss: 0.4072 - val_bounding_box_calculate_iou: 0.8470 - val_class_predictions_accuracy: 0.8942
# Epoch 52/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1787 - bounding_box_loss: 0.0199 - class_predictions_loss: 0.1588 - bounding_box_calculate_iou: 0.8152 - class_predictions_accuracy: 0.9397 - val_loss: 0.3884 - val_bounding_box_loss: 0.0152 - val_class_predictions_loss: 0.3732 - val_bounding_box_calculate_iou: 0.8462 - val_class_predictions_accuracy: 0.8750
# Epoch 53/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1700 - bounding_box_loss: 0.0203 - class_predictions_loss: 0.1497 - bounding_box_calculate_iou: 0.8143 - class_predictions_accuracy: 0.9537 - val_loss: 0.4294 - val_bounding_box_loss: 0.0151 - val_class_predictions_loss: 0.4143 - val_bounding_box_calculate_iou: 0.8473 - val_class_predictions_accuracy: 0.8846
# Epoch 54/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1635 - bounding_box_loss: 0.0189 - class_predictions_loss: 0.1446 - bounding_box_calculate_iou: 0.8223 - class_predictions_accuracy: 0.9386 - val_loss: 0.4673 - val_bounding_box_loss: 0.0156 - val_class_predictions_loss: 0.4517 - val_bounding_box_calculate_iou: 0.8487 - val_class_predictions_accuracy: 0.8654
# Epoch 55/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1521 - bounding_box_loss: 0.0185 - class_predictions_loss: 0.1336 - bounding_box_calculate_iou: 0.8189 - class_predictions_accuracy: 0.9483 - val_loss: 0.4718 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.4569 - val_bounding_box_calculate_iou: 0.8482 - val_class_predictions_accuracy: 0.8846
# Epoch 56/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1875 - bounding_box_loss: 0.0193 - class_predictions_loss: 0.1683 - bounding_box_calculate_iou: 0.8195 - class_predictions_accuracy: 0.9397 - val_loss: 0.4266 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.4117 - val_bounding_box_calculate_iou: 0.8482 - val_class_predictions_accuracy: 0.8654
# Epoch 57/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1744 - bounding_box_loss: 0.0185 - class_predictions_loss: 0.1559 - bounding_box_calculate_iou: 0.8208 - class_predictions_accuracy: 0.9462 - val_loss: 0.4149 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.3999 - val_bounding_box_calculate_iou: 0.8482 - val_class_predictions_accuracy: 0.8942
# Epoch 58/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1489 - bounding_box_loss: 0.0186 - class_predictions_loss: 0.1303 - bounding_box_calculate_iou: 0.8197 - class_predictions_accuracy: 0.9505 - val_loss: 0.4702 - val_bounding_box_loss: 0.0152 - val_class_predictions_loss: 0.4550 - val_bounding_box_calculate_iou: 0.8443 - val_class_predictions_accuracy: 0.8846
# Epoch 59/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1537 - bounding_box_loss: 0.0176 - class_predictions_loss: 0.1360 - bounding_box_calculate_iou: 0.8238 - class_predictions_accuracy: 0.9494 - val_loss: 0.5156 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.5007 - val_bounding_box_calculate_iou: 0.8488 - val_class_predictions_accuracy: 0.8654
# Epoch 60/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1252 - bounding_box_loss: 0.0188 - class_predictions_loss: 0.1064 - bounding_box_calculate_iou: 0.8200 - class_predictions_accuracy: 0.9602 - val_loss: 0.4326 - val_bounding_box_loss: 0.0149 - val_class_predictions_loss: 0.4177 - val_bounding_box_calculate_iou: 0.8491 - val_class_predictions_accuracy: 0.9135
# Epoch 61/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1118 - bounding_box_loss: 0.0181 - class_predictions_loss: 0.0938 - bounding_box_calculate_iou: 0.8252 - class_predictions_accuracy: 0.9688 - val_loss: 0.4545 - val_bounding_box_loss: 0.0146 - val_class_predictions_loss: 0.4398 - val_bounding_box_calculate_iou: 0.8517 - val_class_predictions_accuracy: 0.8942
# Epoch 62/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.1620 - bounding_box_loss: 0.0181 - class_predictions_loss: 0.1440 - bounding_box_calculate_iou: 0.8207 - class_predictions_accuracy: 0.9419 - val_loss: 0.3772 - val_bounding_box_loss: 0.0155 - val_class_predictions_loss: 0.3616 - val_bounding_box_calculate_iou: 0.8410 - val_class_predictions_accuracy: 0.9038
# Epoch 63/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1658 - bounding_box_loss: 0.0178 - class_predictions_loss: 0.1480 - bounding_box_calculate_iou: 0.8279 - class_predictions_accuracy: 0.9462 - val_loss: 0.3521 - val_bounding_box_loss: 0.0151 - val_class_predictions_loss: 0.3370 - val_bounding_box_calculate_iou: 0.8448 - val_class_predictions_accuracy: 0.8846
# Epoch 64/100
# 30/30 [==============================] - 1s 50ms/step - loss: 0.1411 - bounding_box_loss: 0.0180 - class_predictions_loss: 0.1231 - bounding_box_calculate_iou: 0.8248 - class_predictions_accuracy: 0.9516 - val_loss: 0.5246 - val_bounding_box_loss: 0.0162 - val_class_predictions_loss: 0.5084 - val_bounding_box_calculate_iou: 0.8401 - val_class_predictions_accuracy: 0.8846
# Epoch 65/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1621 - bounding_box_loss: 0.0184 - class_predictions_loss: 0.1438 - bounding_box_calculate_iou: 0.8269 - class_predictions_accuracy: 0.9462 - val_loss: 0.3754 - val_bounding_box_loss: 0.0161 - val_class_predictions_loss: 0.3593 - val_bounding_box_calculate_iou: 0.8351 - val_class_predictions_accuracy: 0.8942
# Epoch 66/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1500 - bounding_box_loss: 0.0167 - class_predictions_loss: 0.1333 - bounding_box_calculate_iou: 0.8285 - class_predictions_accuracy: 0.9505 - val_loss: 0.4364 - val_bounding_box_loss: 0.0153 - val_class_predictions_loss: 0.4211 - val_bounding_box_calculate_iou: 0.8458 - val_class_predictions_accuracy: 0.9135
# Epoch 67/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1364 - bounding_box_loss: 0.0168 - class_predictions_loss: 0.1196 - bounding_box_calculate_iou: 0.8263 - class_predictions_accuracy: 0.9623 - val_loss: 0.4215 - val_bounding_box_loss: 0.0153 - val_class_predictions_loss: 0.4062 - val_bounding_box_calculate_iou: 0.8468 - val_class_predictions_accuracy: 0.8846
# Epoch 68/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1185 - bounding_box_loss: 0.0171 - class_predictions_loss: 0.1015 - bounding_box_calculate_iou: 0.8286 - class_predictions_accuracy: 0.9623 - val_loss: 0.5516 - val_bounding_box_loss: 0.0154 - val_class_predictions_loss: 0.5362 - val_bounding_box_calculate_iou: 0.8421 - val_class_predictions_accuracy: 0.8846
# Epoch 69/100
# 30/30 [==============================] - 2s 51ms/step - loss: 0.1323 - bounding_box_loss: 0.0173 - class_predictions_loss: 0.1150 - bounding_box_calculate_iou: 0.8247 - class_predictions_accuracy: 0.9612 - val_loss: 0.4693 - val_bounding_box_loss: 0.0152 - val_class_predictions_loss: 0.4541 - val_bounding_box_calculate_iou: 0.8463 - val_class_predictions_accuracy: 0.8942
# Epoch 70/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1035 - bounding_box_loss: 0.0166 - class_predictions_loss: 0.0869 - bounding_box_calculate_iou: 0.8232 - class_predictions_accuracy: 0.9666 - val_loss: 0.5241 - val_bounding_box_loss: 0.0147 - val_class_predictions_loss: 0.5094 - val_bounding_box_calculate_iou: 0.8469 - val_class_predictions_accuracy: 0.8750
# Epoch 71/100
# 30/30 [==============================] - 2s 50ms/step - loss: 0.1223 - bounding_box_loss: 0.0172 - class_predictions_loss: 0.1050 - bounding_box_calculate_iou: 0.8268 - class_predictions_accuracy: 0.9612 - val_loss: 0.5266 - val_bounding_box_loss: 0.0146 - val_class_predictions_loss: 0.5120 - val_bounding_box_calculate_iou: 0.8482 - val_class_predictions_accuracy: 0.8750

# %%
plt.plot(history.history['class_predictions_accuracy'])
plt.plot(history.history['val_class_predictions_accuracy'])
plt.title('Prediction Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
model_file = os.path.join(new_folder, 'class predictions accuracy.png')
plt.savefig(model_file)
plt.show()

# %%
plt.plot(history.history['bounding_box_loss'])
plt.plot(history.history['val_bounding_box_loss'])
plt.title('Bounding Box Mean Squared Error')
plt.ylabel('Mean Squared Error')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
model_file = os.path.join(new_folder, 'bounding box mean squared error.png')
plt.savefig(model_file)
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss during Training')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
model_file = os.path.join(new_folder, 'loss.png')
plt.savefig(model_file,dpi=600, facecolor='w')
plt.show()

# %%
plt.plot(history.history['bounding_box_calculate_iou'])
plt.plot(history.history['val_bounding_box_calculate_iou'])
plt.title('Intersection over Union during Training')
plt.ylabel('IoU')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
model_file = os.path.join(new_folder, 'IoU.png')
plt.savefig(model_file,dpi=600, facecolor='w')
plt.show()

# %%
from IPython.display import display
from PIL import Image
for i in range(0, 10):
    image = x_test[i].numpy().astype("uint8")
    # Add an additional dimension for batch size
    image = np.expand_dims(image, axis=0)
    x_center_actual = bounding_boxes_y_test[i][0] * image_size
    y_center_actual = bounding_boxes_y_test[i][1] * image_size
    width_actual = bounding_boxes_y_test[i][2] * image_size
    height_actual = bounding_boxes_y_test[i][3] * image_size

    # Calculate x_min, y_min, x_max, and y_max based on the center coordinates, width/heigth and input size
    x_min_actual = int(x_center_actual - (width_actual / 2))
    y_min_actual = int( y_center_actual - (height_actual / 2))
    x_max_actual = x_min_actual + int(width_actual)
    y_max_actual = y_min_actual + int(height_actual)

    top_left_actual = (x_min_actual, y_min_actual)
    bottom_right_actual = (x_max_actual, y_max_actual)




    predictions = model(image)


    # Extract the bounding box center coordinates from predictions
    predicted_box_coords = predictions[0].numpy()[0]
    print('predicted_box_coords: ', predicted_box_coords)
    print('actual_box_coords', bounding_boxes_y_test[i].numpy())
    x_center, y_center = predicted_box_coords[0] * image_size,  predicted_box_coords[1] * image_size
    width, height = predicted_box_coords[2] * image_size,  predicted_box_coords[3] * image_size

    #Extract the prediction label
    predicted_labels = predictions[1].numpy()[0]
    print('predicted_labels: ', predicted_labels)
    predicted_label =  np.argmax(predicted_labels)
    print('predicted_label: ', predicted_label)
    print('actual_label: ', np.argmax(class_labels_y_test[i].numpy()))
    # Calculate x_min, y_min, x_max, and y_max based on the center coordinates, width/heigth and input size
    x_min = int(x_center - (width / 2))
    y_min = int( y_center - (height / 2))
    x_max = x_min + int(width)
    y_max = y_min + int(height)

    top_left = (x_min, y_min)
    bottom_right = (x_max, y_max)

    # Convert image to RGB if it's grayscale
    image = np.squeeze(image)  # Remove the extra batch dimension
    if len(image.shape) == 2:
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

    # Now use the tuple coordinates in the cv2.rectangle function
    color = (0, 255, 0)  # Set green for actual
    # Draw rectangles
    image = cv2.rectangle(image, top_left_actual, bottom_right_actual, color, 2)
    color = (255, 0, 0)  # Set red for prediction
    # Draw rectangles
    cv2.rectangle(image, top_left, bottom_right, color, 2)
    
    # Convert the numpy array to a PIL Image
    image_pil = Image.fromarray(image)

    # Display the image and make it persist
    display(image_pil)
# Out:
# predicted_box_coords:  [0.5031003  0.5075661  0.50963944 0.54431945]
# actual_box_coords [0.5496894  0.4972452  0.60248446 0.57575756]
# predicted_labels:  [1.0000000e+00 3.8033996e-08]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.50517976 0.50018764 0.51186883 0.5544865 ]
# actual_box_coords [0.5689655  0.49746192 0.26293105 0.535533  ]
# predicted_labels:  [1.0000000e+00 2.0043654e-08]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.49051228 0.5016654  0.5262064  0.5505623 ]
# actual_box_coords [0.46666667 0.5911111  0.35555556 0.48      ]
# predicted_labels:  [0.00480533 0.9951946 ]
# predicted_label:  1
# actual_label:  1
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.5015352  0.49758005 0.49077737 0.5418786 ]
# actual_box_coords [0.41222224 0.5675     0.5311111  0.595     ]
# predicted_labels:  [9.999999e-01 7.883389e-08]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.50437737 0.51833856 0.53105414 0.55386746]
# actual_box_coords [0.51875    0.59228975 0.6625     0.5911215 ]
# predicted_labels:  [1.0000000e+00 2.0378721e-08]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.50009125 0.5114567  0.5621638  0.57624424]
# actual_box_coords [0.4751491  0.4377778  0.32604373 0.40888888]
# predicted_labels:  [1.6314983e-04 9.9983680e-01]
# predicted_label:  1
# actual_label:  1
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.4904844  0.48971766 0.4703421  0.5201415 ]
# actual_box_coords [0.50411767 0.49798995 0.39647058 0.35276383]
# predicted_labels:  [0.38525385 0.61474615]
# predicted_label:  1
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.49447846 0.51214933 0.4974325  0.52672446]
# actual_box_coords [0.5029412  0.39447236 0.45294118 0.50753766]
# predicted_labels:  [9.9999988e-01 1.2452516e-07]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.49527544 0.51913583 0.5014907  0.5206279 ]
# actual_box_coords [0.49250534 0.4485714  0.6167024  0.51428574]
# predicted_labels:  [9.999981e-01 1.896577e-06]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
# predicted_box_coords:  [0.49428952 0.47890037 0.43766052 0.52181506]
# actual_box_coords [0.3955 0.5545 0.593  0.647 ]
# predicted_labels:  [9.9999762e-01 2.4375497e-06]
# predicted_label:  0
# actual_label:  0
# <PIL.Image.Image image mode=RGB size=224x224>
